# %% [markdown]
# # Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn

# %%
data=pd.read_csv("C:\\Users\\manis\\OneDrive\\Desktop\\flightdata - flightdata.csv")
data.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM  \
# 0  2016        1      1             1            5             DL   N836DN
# 1  2016        1      1             1            5             DL   N964DN
# 2  2016        1      1             1            5             DL   N813DN
# 3  2016        1      1             1            5             DL   N587NW
# 4  2016        1      1             1            5             DL   N836DN
#
#    FL_NUM  ORIGIN_AIRPORT_ID ORIGIN  ...  DEP_DEL15 CRS_ARR_TIME  ARR_TIME  \
# 0    1399              10397    ATL  ...        0.0         2143    2102.0
# 1    1476              11433    DTW  ...        0.0         1435    1439.0
# 2    1597              10397    ATL  ...        0.0         1215    1142.0
# 3    1768              14747    SEA  ...        0.0         1335    1345.0
# 4    1823              14747    SEA  ...        0.0          607     615.0
#
#    ARR_DELAY  ARR_DEL15  CANCELLED  DIVERTED  CRS_ELAPSED_TIME  \
# 0      -41.0        0.0          0         0               338
# 1        4.0        0.0          0         0               110
# 2      -33.0        0.0          0         0               335
# 3       10.0        0.0          0         0               196
# 4        8.0        0.0          0         0               247
#
#    ACTUAL_ELAPSED_TIME  DISTANCE
# 0                295.0      2182
# 1                115.0       528
# 2                300.0      2182
# 3                205.0      1399
# 4                259.0      1927
#
# [5 rows x 25 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11231 entries, 0 to 11230
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 11231 non-null  int64
#  1   QUARTER              11231 non-null  int64
#  2   MONTH                11231 non-null  int64
#  3   DAY_OF_MONTH         11231 non-null  int64
#  4   DAY_OF_WEEK          11231 non-null  int64
#  5   UNIQUE_CARRIER       11231 non-null  object
#  6   TAIL_NUM             11231 non-null  object
#  7   FL_NUM               11231 non-null  int64
#  8   ORIGIN_AIRPORT_ID    11231 non-null  int64
#  9   ORIGIN               11231 non-null  object
#  10  DEST_AIRPORT_ID      11231 non-null  int64
#  11  DEST                 11231 non-null  object
#  12  CRS_DEP_TIME         11231 non-null  int64
#  13  DEP_TIME             11124 non-null  float64
#  14  DEP_DELAY            11124 non-null  float64
#  15  DEP_DEL15            11124 non-null  float64
#  16  CRS_ARR_TIME         11231 non-null  int64
#  17  ARR_TIME             11116 non-null  float64
#  18  ARR_DELAY            11043 non-null  float64
#  19  ARR_DEL15            11043 non-null  float64
#  20  CANCELLED            11231 non-null  int64
#  21  DIVERTED             11231 non-null  int64
#  22  CRS_ELAPSED_TIME     11231 non-null  int64
#  23  ACTUAL_ELAPSED_TIME  11043 non-null  float64
#  24  DISTANCE             11231 non-null  int64
# dtypes: float64(7), int64(14), object(4)
# memory usage: 2.1+ MB

# %%
data.shape
# Out:
# (11231, 25)

# %%
axis = plt.subplots(figsize=(20,14))
sns.heatmap(data.corr(),annot = True)
plt.show()

# %% [markdown]
# # Removing unwanted Columns

# %%
data1=data.drop(columns=["YEAR","ORIGIN_AIRPORT_ID","DEST_AIRPORT_ID"])

# %%
data1.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM  FL_NUM  \
# 0        1      1             1            5             DL   N836DN    1399
# 1        1      1             1            5             DL   N964DN    1476
# 2        1      1             1            5             DL   N813DN    1597
# 3        1      1             1            5             DL   N587NW    1768
# 4        1      1             1            5             DL   N836DN    1823
#
#   ORIGIN DEST  CRS_DEP_TIME  ...  DEP_DEL15  CRS_ARR_TIME  ARR_TIME  \
# 0    ATL  SEA          1905  ...        0.0          2143    2102.0
# 1    DTW  MSP          1345  ...        0.0          1435    1439.0
# 2    ATL  SEA           940  ...        0.0          1215    1142.0
# 3    SEA  MSP           819  ...        0.0          1335    1345.0
# 4    SEA  DTW          2300  ...        0.0           607     615.0
#
#    ARR_DELAY  ARR_DEL15  CANCELLED  DIVERTED  CRS_ELAPSED_TIME  \
# 0      -41.0        0.0          0         0               338
# 1        4.0        0.0          0         0               110
# 2      -33.0        0.0          0         0               335
# 3       10.0        0.0          0         0               196
# 4        8.0        0.0          0         0               247
#
#    ACTUAL_ELAPSED_TIME  DISTANCE
# 0                295.0      2182
# 1                115.0       528
# 2                300.0      2182
# 3                205.0      1399
# 4                259.0      1927
#
# [5 rows x 22 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11231 entries, 0 to 11230
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   QUARTER              11231 non-null  int64
#  1   MONTH                11231 non-null  int64
#  2   DAY_OF_MONTH         11231 non-null  int64
#  3   DAY_OF_WEEK          11231 non-null  int64
#  4   UNIQUE_CARRIER       11231 non-null  object
#  5   TAIL_NUM             11231 non-null  object
#  6   FL_NUM               11231 non-null  int64
#  7   ORIGIN               11231 non-null  object
#  8   DEST                 11231 non-null  object
#  9   CRS_DEP_TIME         11231 non-null  int64
#  10  DEP_TIME             11124 non-null  float64
#  11  DEP_DELAY            11124 non-null  float64
#  12  DEP_DEL15            11124 non-null  float64
#  13  CRS_ARR_TIME         11231 non-null  int64
#  14  ARR_TIME             11116 non-null  float64
#  15  ARR_DELAY            11043 non-null  float64
#  16  ARR_DEL15            11043 non-null  float64
#  17  CANCELLED            11231 non-null  int64
#  18  DIVERTED             11231 non-null  int64
#  19  CRS_ELAPSED_TIME     11231 non-null  int64
#  20  ACTUAL_ELAPSED_TIME  11043 non-null  float64
#  21  DISTANCE             11231 non-null  int64
# dtypes: float64(7), int64(11), object(4)
# memory usage: 1.9+ MB

# %% [markdown]
# # DATA CLEANING

# %%
data.isnull().values.any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# YEAR                     0
# QUARTER                  0
# MONTH                    0
# DAY_OF_MONTH             0
# DAY_OF_WEEK              0
# UNIQUE_CARRIER           0
# TAIL_NUM                 0
# FL_NUM                   0
# ORIGIN_AIRPORT_ID        0
# ORIGIN                   0
# DEST_AIRPORT_ID          0
# DEST                     0
# CRS_DEP_TIME             0
# DEP_TIME               107
# DEP_DELAY              107
# DEP_DEL15              107
# CRS_ARR_TIME             0
# ARR_TIME               115
# ARR_DELAY              188
# ARR_DEL15              188
# CANCELLED                0
# DIVERTED                 0
# CRS_ELAPSED_TIME         0
# ACTUAL_ELAPSED_TIME    188
# DISTANCE                 0
# dtype: int64

# %%
data1.iloc[179,:].isnull(),data1.iloc[179,:]
# Out:
# (QUARTER                False
#  MONTH                  False
#  DAY_OF_MONTH           False
#  DAY_OF_WEEK            False
#  UNIQUE_CARRIER         False
#  TAIL_NUM               False
#  FL_NUM                 False
#  ORIGIN                 False
#  DEST                   False
#  CRS_DEP_TIME           False
#  DEP_TIME                True
#  DEP_DELAY               True
#  DEP_DEL15               True
#  CRS_ARR_TIME           False
#  ARR_TIME                True
#  ARR_DELAY               True
#  ARR_DEL15               True
#  CANCELLED              False
#  DIVERTED               False
#  CRS_ELAPSED_TIME       False
#  ACTUAL_ELAPSED_TIME     True
#  DISTANCE               False
#  Name: 179, dtype: bool,
#  QUARTER                     1
#  MONTH                       1
#  DAY_OF_MONTH               10
#  DAY_OF_WEEK                 7
#  UNIQUE_CARRIER             DL
#  TAIL_NUM               N924DN
#  FL_NUM                     86
#  ORIGIN                    MSP
#  DEST                      DTW
#  CRS_DEP_TIME             1348
#  DEP_TIME                  NaN
#  DEP_DELAY                 NaN
#  DEP_DEL15                 NaN
#  CRS_ARR_TIME             1632
#  ARR_TIME                  NaN
#  ARR_DELAY                 NaN
#  ARR_DEL15                 NaN
#  CANCELLED                   1
#  DIVERTED                    0
#  CRS_ELAPSED_TIME          104
#  ACTUAL_ELAPSED_TIME       NaN
#  DISTANCE                  528
#  Name: 179, dtype: object)

# %%
data1[(data1["TAIL_NUM"]=="N924DN")&(data1["FL_NUM"]==86)]
# Out:
#      QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM  \
# 179        1      1            10            7             DL   N924DN
#
#      FL_NUM ORIGIN DEST  CRS_DEP_TIME  ...  DEP_DEL15  CRS_ARR_TIME  ARR_TIME  \
# 179      86    MSP  DTW          1348  ...        NaN          1632       NaN
#
#      ARR_DELAY  ARR_DEL15  CANCELLED  DIVERTED  CRS_ELAPSED_TIME  \
# 179        NaN        NaN          1         0               104
#
#      ACTUAL_ELAPSED_TIME  DISTANCE
# 179                  NaN       528
#
# [1 rows x 22 columns]

# %%
data1[(data1["DEP_DEL15"]==0)&(data1["ARR_DEL15"]==1)]
# Out:
#        QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK UNIQUE_CARRIER TAIL_NUM  \
# 34           1      1             4            1             DL   N827DN
# 128          1      1             7            4             DL   N931DN
# 146          1      1             8            5             DL   N678DL
# 166          1      1             8            5             DL   N711ZX
# 167          1      1             8            5             DL   N824DN
# ...        ...    ...           ...          ...            ...      ...
# 11120        4     12            29            4             DL   N301DN
# 11168        4     12            30            5             DL   N947DL
# 11173        4     12            31            6             DL   N659DL
# 11187        4     12             3            6             DL   N627DL
# 11203        4     12             9            5             DL   N837DN
#
#        FL_NUM ORIGIN DEST  CRS_DEP_TIME  ...  DEP_DEL15  CRS_ARR_TIME  \
# 34       1770    SEA  MSP          1520  ...        0.0          2032
# 128       744    MSP  ATL          1005  ...        0.0          1334
# 146         8    MSP  ATL          1732  ...        0.0          2105
# 166      1473    SEA  JFK          1110  ...        0.0          1930
# 167      1598    SEA  ATL           620  ...        0.0          1401
# ...       ...    ...  ...           ...  ...        ...           ...
# 11120     811    ATL  MSP          1350  ...        0.0          1532
# 11168     984    ATL  JFK          2055  ...        0.0          2315
# 11173    2610    ATL  MSP           725  ...        0.0           900
# 11187      95    ATL  DTW          1235  ...        0.0          1436
# 11203    2221    MSP  SEA          1120  ...        0.0          1311
#
#        ARR_TIME  ARR_DELAY  ARR_DEL15  CANCELLED  DIVERTED  CRS_ELAPSED_TIME  \
# 34       2048.0       16.0        1.0          0         0               192
# 128      1349.0       15.0        1.0          0         0               149
# 146      2133.0       28.0        1.0          0         0               153
# 166      1950.0       20.0        1.0          0         0               320
# 167      1416.0       15.0        1.0          0         0               281
# ...         ...        ...        ...        ...       ...               ...
# 11120    1552.0       20.0        1.0          0         0               162
# 11168    2330.0       15.0        1.0          0         0               140
# 11173     921.0       21.0        1.0          0         0               155
# 11187    1500.0       24.0        1.0          0         0               121
# 11203    1345.0       34.0        1.0          0         0               231
#
#        ACTUAL_ELAPSED_TIME  DISTANCE
# 34                   207.0      1399
# 128                  159.0       907
# 146                  178.0       907
# 166                  340.0      2422
# 167                  296.0      2182
# ...                    ...       ...
# 11120                185.0       907
# 11168                157.0       760
# 11173                168.0       907
# 11187                131.0       594
# 11203                267.0      1399
#
# [340 rows x 22 columns]

# %%
data1.describe()
# Out:
#             QUARTER         MONTH  DAY_OF_MONTH   DAY_OF_WEEK        FL_NUM  \
# count  11231.000000  11231.000000  11231.000000  11231.000000  11231.000000
# mean       2.544475      6.628973     15.790758      3.960199   1334.325617
# std        1.090701      3.354678      8.782056      1.995257    811.875227
# min        1.000000      1.000000      1.000000      1.000000      7.000000
# 25%        2.000000      4.000000      8.000000      2.000000    624.000000
# 50%        3.000000      7.000000     16.000000      4.000000   1267.000000
# 75%        3.000000      9.000000     23.000000      6.000000   2032.000000
# max        4.000000     12.000000     31.000000      7.000000   2853.000000
#
#        CRS_DEP_TIME      DEP_TIME     DEP_DELAY     DEP_DEL15  CRS_ARR_TIME  \
# count  11231.000000  11124.000000  11124.000000  11124.000000  11231.000000
# mean    1320.798326   1327.189410      8.460266      0.142844   1537.312795
# std      490.737845    500.306462     36.762969      0.349930    502.512494
# min       10.000000      1.000000    -16.000000      0.000000      2.000000
# 25%      905.000000    905.000000     -3.000000      0.000000   1130.000000
# 50%     1320.000000   1324.000000     -1.000000      0.000000   1559.000000
# 75%     1735.000000   1739.000000      4.000000      0.000000   1952.000000
# max     2359.000000   2400.000000    645.000000      1.000000   2359.000000
#
#            ARR_TIME     ARR_DELAY     ARR_DEL15     CANCELLED      DIVERTED  \
# count  11116.000000  11043.000000  11043.000000  11231.000000  11231.000000
# mean    1523.978499     -2.573123      0.124513      0.010150      0.006589
# std      512.536041     39.232521      0.330181      0.100241      0.080908
# min        1.000000    -67.000000      0.000000      0.000000      0.000000
# 25%     1135.000000    -19.000000      0.000000      0.000000      0.000000
# 50%     1547.000000    -10.000000      0.000000      0.000000      0.000000
# 75%     1945.000000      1.000000      0.000000      0.000000      0.000000
# max     2400.000000    615.000000      1.000000      1.000000      1.000000
#
#        CRS_ELAPSED_TIME  ACTUAL_ELAPSED_TIME      DISTANCE
# count      11231.000000         11043.000000  11231.000000
# mean         190.652124           179.661233   1161.031965
# std           78.386317            77.940399    643.683379
# min           93.000000            75.000000    509.000000
# 25%          127.000000           117.000000    594.000000
# 50%          159.000000           149.000000    907.000000
# 75%          255.000000           236.000000   1927.000000
# max          397.000000           428.000000   2422.000000

# %% [markdown]
# # EDA/DATA ANALYSIS

# %%
sns.lineplot(x="DEP_DELAY",y="ARR_DELAY",data=data1)
# Out:
# <AxesSubplot:xlabel='DEP_DELAY', ylabel='ARR_DELAY'>

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,1,1)
plt.scatter(data1["DAY_OF_MONTH"],data1["DEP_DELAY"],color="red")
plt.subplot(2,1,2)
plt.scatter(data1["DAY_OF_WEEK"],data1["ARR_DELAY"],color="yellow")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.boxplot(x="DAY_OF_WEEK",y="DEP_DELAY",data=data1,hue="DEP_DEL15")
# Out:
# <AxesSubplot:xlabel='DAY_OF_WEEK', ylabel='DEP_DELAY'>

# %%
data1.groupby(by="MONTH")["DEP_DEL15"].sum()
# Out:
# MONTH
# 1     113.0
# 2     115.0
# 3     104.0
# 4      96.0
# 5      86.0
# 6     168.0
# 7     219.0
# 8     246.0
# 9      88.0
# 10     86.0
# 11     66.0
# 12    202.0
# Name: DEP_DEL15, dtype: float64

# %% [markdown]
# # Feature Extraction

# %%
ms=[6,7,8]
wt=[9,10,11]
sp=[12,1,2,3]
fl=[4,5]
data1["SEASON"]=np.where(data1["MONTH"].isin(ms),0,np.where(data1["MONTH"].isin(wt),1,np.where(data1["MONTH"].isin(sp),2,3)))

# %%
data1["SEASON"].value_counts()
# Out:
# 2    3441
# 0    3184
# 1    2808
# 3    1798
# Name: SEASON, dtype: int64

# %% [markdown]
# # Encoding Catagorical cloumns to numerical

# %%
data1["CANCELLED"]=np.where(data1["CANCELLED"]==1,4,0)

# %%
data1["DIVERTED"]=np.where(data1["DIVERTED"]==1,3,0)

# %%
data1.CANCELLED.unique(),data1.DIVERTED.unique()
# Out:
# (array([0, 4]), array([0, 3]))

# %%
data1["DELAY_15"]=data1["ARR_DEL15"]+data1["DEP_DEL15"]
data1.DELAY_15.unique()
# Out:
# array([ 0.,  1.,  2., nan])

# %%
data1["DELAY_15"].fillna(0,inplace=True)
data1.DELAY_15.unique()
# Out:
# array([0., 1., 2.])

# %%
data1["NDELAY"]=data1["DELAY_15"]+data1["CANCELLED"]+data1["DIVERTED"]

# %%
data1.NDELAY.unique()
# Out:
# array([0., 1., 2., 3., 4.])

# %%
len(data1["TAIL_NUM"].value_counts()),len(data1["FL_NUM"].value_counts())
# Out:
# (789, 690)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11231 entries, 0 to 11230
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   QUARTER              11231 non-null  int64
#  1   MONTH                11231 non-null  int64
#  2   DAY_OF_MONTH         11231 non-null  int64
#  3   DAY_OF_WEEK          11231 non-null  int64
#  4   UNIQUE_CARRIER       11231 non-null  object
#  5   TAIL_NUM             11231 non-null  object
#  6   FL_NUM               11231 non-null  int64
#  7   ORIGIN               11231 non-null  object
#  8   DEST                 11231 non-null  object
#  9   CRS_DEP_TIME         11231 non-null  int64
#  10  DEP_TIME             11124 non-null  float64
#  11  DEP_DELAY            11124 non-null  float64
#  12  DEP_DEL15            11124 non-null  float64
#  13  CRS_ARR_TIME         11231 non-null  int64
#  14  ARR_TIME             11116 non-null  float64
#  15  ARR_DELAY            11043 non-null  float64
#  16  ARR_DEL15            11043 non-null  float64
#  17  CANCELLED            11231 non-null  int32
#  18  DIVERTED             11231 non-null  int32
#  19  CRS_ELAPSED_TIME     11231 non-null  int64
#  20  ACTUAL_ELAPSED_TIME  11043 non-null  float64
#  21  DISTANCE             11231 non-null  int64
#  22  SEASON               11231 non-null  int32
#  23  DELAY_15             11231 non-null  float64
#  24  NDELAY               11231 non-null  float64
# dtypes: float64(9), int32(3), int64(9), object(4)
# memory usage: 2.0+ MB

# %%
clm=["UNIQUE_CARRIER","DEP_TIME","DEP_DELAY","DEP_DEL15","ARR_TIME","ARR_DELAY","ARR_DEL15","CANCELLED","DIVERTED",
    "ACTUAL_ELAPSED_TIME","DELAY_15"]
data2=data1.drop(columns=clm)
data2.head()
# Out:
#    QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK TAIL_NUM  FL_NUM ORIGIN DEST  \
# 0        1      1             1            5   N836DN    1399    ATL  SEA
# 1        1      1             1            5   N964DN    1476    DTW  MSP
# 2        1      1             1            5   N813DN    1597    ATL  SEA
# 3        1      1             1            5   N587NW    1768    SEA  MSP
# 4        1      1             1            5   N836DN    1823    SEA  DTW
#
#    CRS_DEP_TIME  CRS_ARR_TIME  CRS_ELAPSED_TIME  DISTANCE  SEASON  NDELAY
# 0          1905          2143               338      2182       2     0.0
# 1          1345          1435               110       528       2     0.0
# 2           940          1215               335      2182       2     0.0
# 3           819          1335               196      1399       2     0.0
# 4          2300           607               247      1927       2     0.0

# %%
data3=data2.drop(columns=["TAIL_NUM","FL_NUM"])

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11231 entries, 0 to 11230
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   QUARTER           11231 non-null  int64
#  1   MONTH             11231 non-null  int64
#  2   DAY_OF_MONTH      11231 non-null  int64
#  3   DAY_OF_WEEK       11231 non-null  int64
#  4   ORIGIN            11231 non-null  object
#  5   DEST              11231 non-null  object
#  6   CRS_DEP_TIME      11231 non-null  int64
#  7   CRS_ARR_TIME      11231 non-null  int64
#  8   CRS_ELAPSED_TIME  11231 non-null  int64
#  9   DISTANCE          11231 non-null  int64
#  10  SEASON            11231 non-null  int32
#  11  NDELAY            11231 non-null  float64
# dtypes: float64(1), int32(1), int64(8), object(2)
# memory usage: 1009.2+ KB

# %%
data3.hist(figsize=(12,8))
# Out:
# array([[<AxesSubplot:title={'center':'QUARTER'}>,
#         <AxesSubplot:title={'center':'MONTH'}>,
#         <AxesSubplot:title={'center':'DAY_OF_MONTH'}>],
#        [<AxesSubplot:title={'center':'DAY_OF_WEEK'}>,
#         <AxesSubplot:title={'center':'CRS_DEP_TIME'}>,
#         <AxesSubplot:title={'center':'CRS_ARR_TIME'}>],
#        [<AxesSubplot:title={'center':'CRS_ELAPSED_TIME'}>,
#         <AxesSubplot:title={'center':'DISTANCE'}>,
#         <AxesSubplot:title={'center':'SEASON'}>],
#        [<AxesSubplot:title={'center':'NDELAY'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data3.NDELAY.value_counts()
# Out:
# 0.0    9130
# 2.0    1035
# 1.0     878
# 4.0     114
# 3.0      74
# Name: NDELAY, dtype: int64

# %% [markdown]
# # Splitting dependent and independent variables

# %%
x=data2.drop(columns=["NDELAY","TAIL_NUM"])
y=data2.NDELAY

# %% [markdown]
# # Encoding Categorical cloumns to numerical

# %%
x["ORIGIN"].replace({"ATL":1,'DTW':2,'JFK':3,'MSP':4,'SEA':5},inplace=True)
x["DEST"].replace({"ATL":1,'DTW':2,'JFK':3,'MSP':4,'SEA':5},inplace=True)

# %%
pip install imblearn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imblearn in c:\users\manis\appdata\roaming\python\python39\site-packages (0.0)
# Requirement already satisfied: imbalanced-learn in c:\users\manis\appdata\roaming\python\python39\site-packages (from imblearn) (0.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.9.1)
# Requirement already satisfied: scikit-learn>=1.1.0 in c:\users\manis\appdata\roaming\python\python39\site-packages (from imbalanced-learn->imblearn) (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.21.5)
# Requirement already satisfied: joblib>=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from imbalanced-learn->imblearn) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from imblearn.combine import SMOTETomek 
smote=SMOTETomek(sampling_strategy={1:2000,2:2000,3:400,4:700},random_state=42)
x1,y2=smote.fit_resample(x,y)
y2.value_counts()
# Out:
# 0.0    8316
# 1.0    1537
# 2.0    1493
# 4.0     634
# 3.0     340
# Name: NDELAY, dtype: int64

# %%
#x1=pd.read_csv("C:\\Users\\manis\\OneDrive\\Desktop\\x.csv")
#y2=pd.read_csv("C:\\Users\\manis\\OneDrive\\Desktop\\y.csv")
from sklearn.utils import shuffle
X,Y=shuffle(x1,y2,random_state=72)
X.head()
# Out:
#        QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  FL_NUM  ORIGIN  DEST  \
# 5816         3      8            16            2     786       2     1
# 475          1      1            25            1    1173       4     2
# 10952        2      6            25            2    2547       5     4
# 8363         4     11            14            1    1247       5     1
# 11452        1      2            19            2    1232       1     4
#
#        CRS_DEP_TIME  CRS_ARR_TIME  CRS_ELAPSED_TIME  DISTANCE  SEASON
# 5816           1400          1603               123       594       0
# 475             830          1114               104       528       2
# 10952          1894            16               197      1399       0
# 8363            900          1653               293      2182       1
# 11452          2079          2209               149       744       2

# %% [markdown]
# # Split train test data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x1,y2,test_size=0.2,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((9856, 12), (2464, 12))

# %% [markdown]
# # Model building

# %% [markdown]
# # Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dc=DecisionTreeClassifier()
dc.fit(x_train,y_train)
dc.score(x_test,y_test)
# Out:
# 0.7556818181818182

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=50,random_state=42)
rf.fit(x_train,y_train)
rf.score(x_test,y_test)
# Out:
# 0.8368506493506493

# %%
pd.DataFrame(rf.predict(x_test)).value_counts()
# Out:
# 0.0    1881
# 1.0     223
# 2.0     213
# 4.0     106
# 3.0      41
# dtype: int64

# %%
x_test.iloc[[99],:]
x_test
# Out:
#        QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  FL_NUM  ORIGIN  DEST  \
# 1825         1      3            20            7    2790       1     2
# 357          1      1            13            3    2440       5     4
# 4165         2      6            16            4    2440       5     4
# 7969         4     10             3            1     177       1     4
# 3482         2      5            22            7    2032       4     3
# ...        ...    ...           ...          ...     ...     ...   ...
# 11752        2      6            20            2    2745       2     5
# 1284         1      2            24            3    2834       4     5
# 4015         2      6            11            6    2221       4     5
# 5272         3      7            30            6    2032       4     3
# 10401        2      6            24            5    1290       1     2
#
#        CRS_DEP_TIME  CRS_ARR_TIME  CRS_ELAPSED_TIME  DISTANCE  SEASON
# 1825           1205          1407               122       594       2
# 357              35           550               195      1399       2
# 4165             45           558               193      1399       0
# 7969           1501          1649               168       907       1
# 3482            703          1045               162      1029       3
# ...             ...           ...               ...       ...     ...
# 11752          1774          2116               377      2377       0
# 1284            659           854               235      1399       2
# 4015            900          1045               225      1399       0
# 5272            700          1049               169      1029       0
# 10401          2217            14               117       594       0
#
# [2464 rows x 12 columns]

# %%
y_test.iloc[[8,21,910]]
# Out:
# 2318     0.0
# 12270    4.0
# 7414     0.0
# Name: NDELAY, dtype: float64

# %%
rf.predict(x_test.iloc[[99],:])
# Out:
# array([0.])

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr1=LogisticRegression(solver='sag')
lr1.fit(x_train,y_train)
lr1.score(x_test,y_test)
# Out:
# C:\Users\manis\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 0.6830357142857143

# %% [markdown]
# # SVM

# %%
from sklearn.svm import SVC
svm=SVC(kernel='sigmoid')
svm.fit(x_train,y_train)
svm.score(x_test,y_test)
# Out:
# 0.6128246753246753

# %%
pd.DataFrame(svm.predict(x_test)).value_counts()
# Out:
# 0.0    2167
# 2.0     230
# 4.0      67
# dtype: int64

# %%
pd.DataFrame(y_test).value_counts()
# Out:
# NDELAY
# 0.0       1683
# 1.0        308
# 2.0        288
# 4.0        130
# 3.0         55
# dtype: int64

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
knn.score(x_test,y_test)
# Out:
# 0.7280844155844156

# %% [markdown]
# Evaluating Decision Tree and Random Forest

# %% [markdown]
# # Evaluation of Random Forest

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
pred=rf.predict(x_test)
cm=confusion_matrix(y_test, pred)
#plt.figure(figsize=(10,6))
#sns.heatmap(cm, annot=True,cmap='winter',linewidths=0.3, linecolor='black',annot_kws={"size": 20})
TP=cm[0][0]
TN=cm[1][1]
FN=cm[1][0]
FP=cm[0][1]
#print(round(accuracy_score(prediction3,y_test)*100,2))
#print('Testing Accuracy for knn',(TP+TN)/(TP+TN+FN+FP))
print('Testing Sensitivity for Random Forest',(TP/(TP+FN)))
print('Testing Specificity for Random Forest',(TN/(TN+FP)))
print('Testing Precision for Random Forest',(TP/(TP+FP)))
print('Testing accuracy for Random Forest',accuracy_score(y_test, pred))
# Out:
# Testing Sensitivity for Random Forest 0.9360230547550432
# Testing Specificity for Random Forest 0.8716577540106952
# Testing Precision for Random Forest 0.9854368932038835
# Testing accuracy for Random Forest 0.8368506493506493

# %%
print(classification_report(y_test,pred))#RandomForest
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.96      0.91      1683
#          1.0       0.73      0.53      0.61       308
#          2.0       0.67      0.49      0.57       288
#          3.0       0.88      0.65      0.75        55
#          4.0       0.92      0.75      0.82       130
#
#     accuracy                           0.84      2464
#    macro avg       0.81      0.68      0.73      2464
# weighted avg       0.83      0.84      0.83      2464

# %% [markdown]
# # Evaluation Of Decission Tree

# %%
pred1=dc.predict(x_test)
cm1=confusion_matrix(y_test, pred1)
#plt.figure(figsize=(10,6))
#sns.heatmap(cm1, annot=True,cmap='winter',linewidths=0.3, linecolor='black',annot_kws={"size": 20})
TP=cm1[0][0]
TN=cm1[1][1]
FN=cm1[1][0]
FP=cm1[0][1]
#print(round(accuracy_score(prediction3,y_test)*100,2))
print('Testing Accuracy for Decision Tree',(TP+TN)/(TP+TN+FN+FP))
print('Testing Sensitivity for Decision Tree',(TP/(TP+FN)))
print('Testing Specificity for Decision Tree',(TN/(TN+FP)))
print('Testing Precision for Decision Tree',(TP/(TP+FP)))
print('Testing accuracy for Decision Tree',accuracy_score(y_test, pred1))
# Out:
# Testing Accuracy for Decision Tree 0.8864774624373957
# Testing Sensitivity for Decision Tree 0.9405228758169935
# Testing Specificity for Decision Tree 0.5767790262172284
# Testing Precision for Decision Tree 0.9271907216494846
# Testing accuracy for Decision Tree 0.7556818181818182

# %%
print(classification_report(y_test,pred1))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.88      0.86      0.87      1683
#          1.0       0.47      0.50      0.49       308
#          2.0       0.46      0.52      0.49       288
#          3.0       0.48      0.53      0.50        55
#          4.0       0.77      0.70      0.73       130
#
#     accuracy                           0.76      2464
#    macro avg       0.61      0.62      0.62      2464
# weighted avg       0.76      0.76      0.76      2464

# %%
import pickle
pickle.dump(rf,open("rfmodel.pkl",'wb'))

# %% [markdown]
# # testing

# %%
loaded_model=pickle.load(open("rfmodel.pkl","rb"))
a=[2,6,25,2,2560,5,4,1894,16,197,1399,0]
a=pd.DataFrame(a)
a=a.transpose()
h=loaded_model.predict(a)
h[0]
# Out:
# C:\Users\manis\AppData\Roaming\Python\Python39\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 2.0
